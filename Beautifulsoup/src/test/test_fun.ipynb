# %%
import requests
from bs4 import BeautifulSoup
url  = "https://www.apollopharmacy.in/medicine/benadryl-cough-formula-syrup-450ml"

r = requests.get(url)
soup = BeautifulSoup(r.content, 'html.parser')

print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <link href="https://images.apollo247.in" rel="preconnect"/>
#   <link crossorigin="" href="https://www.googletagmanager.com" rel="preconnect"/>
#   <link crossorigin="" href="https://www.googleadservices.com" rel="preconnect"/>
#   <link crossorigin="" href="https://www.google-analytics.com" rel="preconnect"/>
#   <link crossorigin="" href="https://stats.g.doubleclick.net" rel="preconnect"/>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <link as="image" href="https://images.apollo247.in/pub/media/catalog/product/b/e/ben0005_1_1.jpg?tr=w-164,q-80,f-webp,dpr-false,c-at_max" rel="preload"/>
#   <link as="image" href="https://images.apollo247.in/pub/media/catalog/product/b/e/ben0005_2.jpg?tr=w-164,q-80,f-webp,dpr-false,c-at_max" rel="preload"/>
#   <link as="image" href="https://images.apollo247.in/pub/media/catalog/product/b/e/ben0005_3.jpg?tr=w-164,q-80,f-webp,dpr-false,c-at_max" rel="preload"/>
#   <link data-precedence="next" href="https://www.apollopharmacy.in/assets/production/aph-pharmacy-frontend/_next/static/css/d1ead426198ee0b4.css" rel="stylesheet"/>
#   <link data-precedence="next" href="https://www.apollopharmacy.in/assets/production/aph-pharmacy-frontend/_next/static/css/102e7dbdc8d8f354.css" rel="stylesheet"/>
#   <link data-precedence="next" href="https://www.apollopharmacy.in/assets/production/aph-pharmacy-frontend/_next/static/css/8652ddc10f9d080f.css" rel="stylesheet"/>
#   <link data-precedence="next" href="https://www.apollopharmacy.in/assets/production/aph-pharmacy-frontend/_next/static/css/e6377212b6dbfc70.css" rel="stylesheet"/>
#   <link data-precedence="next" href="https://www.apollopharmacy.in/assets/production/aph-pharmacy-frontend/_next/static/css/1ea750b3d9fa11d4.css" rel="stylesheet"/>
#   <link as="script" fetchpriority="low" href="https://www.apollopharmacy.in/assets/production/aph-pharmacy-frontend/_next/static/chunks/webpack-5e6a84198ac9af07.js" rel="preload"/>
#   <script async="" src="https://www.apollopharmacy.in/assets/production/aph-pharmacy-frontend/_next/static/chunks/fd9d1056-dcdd25d349349e8b.js">
#   </script>
#   <script async="" src="https://www.apollopharmacy.in/assets/production/aph-pharmacy-frontend/_next/static/chunks/2472-76948248073f2f26.js">
#   </script>
#   <script async="" src="https://www.apollopharmacy.in/assets/production/aph-pharmacy-frontend/_next/static/chunks/main-app-6c9e48097846cc59.js">
#   </script>
#   <script async="" src="https://www.apollopharmacy.in/assets/production/aph-pharmacy-frontend/_next/static/chunks/fe69a9a4-984bd6d7e3504190.js">
#   </script>
#   <script async="" src="https://www.apollopharmacy.in/assets/production/aph-pharmacy-frontend/_next/static/chunks/b69a1e92-8f649f7353060387.js">
#   </script>
#   <script async="" src="https://www.apollopharmacy.in/assets/production/aph-pharmacy-frontend/_next/static/chunks/cebad358-20d4237590ad883b.js">
#   </script>
#   <script async="" src="https://www.apollopharmacy.in/assets/production/aph-pharmacy-frontend/_next/static/chunks/6473-3b1d60e94e4cf30c.js">
#   </script>
#   <script async="" src="https://www.apollopharmacy.in/assets/production/aph-pharmacy-frontend/_next/static/chunks/8879-f45792323597fd17.js">
#   </script>
#   <script async="" src="https://www.apollopharmacy.in/assets/production/aph-pharmacy-frontend/_next/static/chunks/3042-dfdb5ea2f9b4ebc0.js">
#   </script>
#   <script async="" src="https://www.apollopharmacy.in/assets/production/aph-pharmacy-frontend/_next/static/chunks/9088-1edb296956d1e3bd.js">
#   </script>
#   <script async="" src="https://www.apollopharmacy.in/assets/production/aph-pharmacy-frontend/_next/static/chunks/3337-101ae4c5a44206a5.js">
#   </script>
#   <script async="" src="https://www.apollopharmacy.in/assets/production/aph-pharmacy-frontend/_next/static/chunks/71-97ac8e9a735820d9.js">
#   </script>
#   <script async="" src="https://www.apollopharmacy.in/assets/production/aph-pharmacy-frontend/_next/static/chunks/3230-bf9b912d3f7effc4.js">
#   </script>
#   <script async="" src="https://www.apollopharmacy.in/assets/production/aph-pharmacy-frontend/_next/static/chunks/8938-e95800dae6aa1ed8.js">
#   </script>
#   <script async="" src="https://www.apollopharmacy.in/assets/production/aph-pharmacy-frontend/_next/static/chunks/4747-76052cdb069b4f08.js">
#   </script>
#   <script async="" src="https://www.apollopharmacy.in/assets/production/aph-pharmacy-frontend/_next/static/chunks/5290-3497d6ec12e57f30.js">
#   </script>
#   <script async="" src="https://www.apollopharmacy.in/assets/production/aph-pharmacy-frontend/_next/static/chunks/app/medicine/%5Bsku%5D/page-f7aa96c15b4d2ea7.js">
#   </script>
#   <meta content="DPR, Width, Viewport-Width" http-equiv="Accept-CH"/>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#   <meta content="#1a504c" name="theme-color"/>
#   <link href="https://images.apollo247.in/images/favicon.png" rel="shortcut icon" type="image/x-icon"/>
#   <title>
#    Benadryl Cough Formula Syrup, 450 ml Price, Uses, Side Effects, Composition - Apollo Pharmacy
#   </title>
#   <meta content="Apollo Pharmacy - Buy Benadryl Cough Formula Syrup, 450 ml, 450 at Rs.276 in India. Order Benadryl Cough Formula Syrup, 450 ml online and get the medicine delivered within 4 hours at your doorsteps. Know the uses, side effects, composition, precautions and more about Benadryl Cough Formula Syrup, 450 ml." name="description"/>
#   <meta content="buy Benadryl Cough Formula Syrup, 450 ml, Benadryl Cough Formula Syrup, 450 ml Price, Benadryl Cough Formula Syrup, 450 ml uses, Benadryl Cough Formula Syrup, 450 ml side effects, Benadryl Cough Formula Syrup, 450 ml Composition" name="keywords"/>
#   <meta content="index, follow" name="robots"/>
#   <link href="https://www.apollopharmacy.in/medicine/benadryl-cough-formula-syrup-450ml" rel="canonical"/>
#   <meta content="Benadryl Cough Formula Syrup, 450 ml Price, Uses, Side Effects, Composition - Apollo Pharmacy" property="og:title"/>
#   <meta content="Apollo Pharmacy - Buy Benadryl Cough Formula Syrup, 450 ml, 450 at Rs.276 in India. Order Benadryl Cough Formula Syrup, 450 ml online and get the medicine delivered within 4 hours at your doorsteps. Know the uses, side effects, composition, precautions and more about Benadryl Cough Formula Syrup, 450 ml." property="og:description"/>
#   <meta content="https://www.apollopharmacy.in/medicine/benadryl-cough-formula-syrup-450ml" property="og:url"/>
#   <meta content="Apollo Pharmacy" property="og:site_name"/>
#   <meta content="https://images.apollo247.in/pub/media/catalog/product/b/e/ben0005_1_1.jpg" property="og:image"/>
#   <meta content="summary" name="twitter:card"/>
#   <meta content="Benadryl Cough Formula Syrup, 450 ml Price, Uses, Side Effects, Composition - Apollo Pharmacy" name="twitter:title"/>
#   <meta content="Apollo Pharmacy - Buy Benadryl Cough Formula Syrup, 450 ml, 450 at Rs.276 in India. Order Benadryl Cough Formula Syrup, 450 ml online and get the medicine delivered within 4 hours at your doorsteps. Know the uses, side effects, composition, precautions and more about Benadryl Cough Formula Syrup, 450 ml." name="twitter:description"/>
#   <meta content="https://images.apollo247.in/pub/media/catalog/product/b/e/ben0005_1_1.jpg" name="twitter:image"/>
#   <style id="critical-css">
#    .initialKeenStyle {
#   display: flex;
#   position: relative;
#   border-radius: 10px;
#   overflow: hidden;
#   > div {
#     min-width: 16.6%;
#     padding-right: 20px;
#     @media screen and (max-width: 767.9px) {
#       min-width: 112px;
#       padding-right: 10px;
#     }
#   }
#   &.initialBannerStyle {
#     > div {
#       border-radius: 10px;
#       @media screen and (min-width: 768px) {
#         min-height: 214px;
#         min-width: 33.33%;
#         &:first-child {
#           transform: translate3d(0, 0, 0);
#         }
#         &:nth-child(2) {
#           transform: translate3d(10px, 0, 0);
#         }
#         &:nth-child(3) {
#           transform: translate3d(20px, 0, 0);
#           //padding-right: 0;
#         }
#       }
#       @media screen and (max-width: 767.9px) {
#         min-height: 176px;
#         min-width: 100%;
#       }
#     }
#   }
# }
# .buyMedicineTitle {
#   font-size: 30px;
#   margin-bottom: 24px;
#   line-height: 36px;
#   font-weight: 700;
#   color: #fff;
# }
# .dots {
#   position: absolute;
#   left: 50%;
#   transform: translateX(-50%);
#   bottom: -10px;
#   background: #fff;
#   display: flex;
#   justify-content: center;
#   width: 100%;
# }
# .initialPdpStyle {
#   //width: 100%;
#   overflow: hidden;
#   display: flex;
#   align-items: center;
#   @media screen and (max-width: 767.9px) {
#     min-height: 359px;
#     position: relative;
#     flex-shrink: 0;
#     &::before {
#       content: "";
#       position: absolute;
#       height: calc(100% - 20px);
#       margin-bottom: 20px;
#       width: 100%;
#       z-index: 99;
#       // background: #f1f1ef;
#     }
#   }
#   > div {
#     width: 100%;
#     flex-shrink: 0;
#   }
# }
# .pdpThumbShimmer {
#   display: flex;
#   width: 100%;
#   overflow: hidden;
#   @media screen and (max-width: 767.9px) {
#     min-height: 60px;
#     position: relative;
#     &::before {
#       content: "";
#       position: absolute;
#       height: 100%;
#       width: 100%;
#       z-index: 99;
#       border-radius: 8px;
#     }
#     > div {
#       min-width: 60px;
#       margin-right: 12px;
#     }
#   }
# }
# .dotShimmer {
#   &::before {
#     content: "";
#     position: absolute;
#     height: 100%;
#     width: 100%;
#     z-index: 99;
#     background: #fff;
#   }
# }
# //pdp thumbmail carousel arrow
# .arrow {
#   border-radius: 6px;
#   z-index: 3;
#   width: 32px;
#   height: 32px;
#   position: absolute;
#   svg {
#     width: 12px;
#   }
# }
#
# .dynamicMainContent {
#   background: $white;
#   padding-top: 32px;
#   min-height: 1000px;
#   @include for-size(phone) {
#     min-height: 400px;
#   }
#   [class^="GridSection_"] {
#     + [class^="GridSection_"] {
#       margin-top: -20px;
#     }
#   }
# }
#
# .mainContent {
#   background: $white;
#   @include for-size(phone) {
#     background: $lightGrey;
#   }
# }
#
# .medicineMainSection {
#   background: $white;
#   padding: 20px 30px;
#   position: relative;
#   box-shadow: none;
#   @include flex(flex-start, unset, row);
#   align-items: flex-start;
#   @include for-size(phone) {
#     flex-direction: column;
#     padding: 0;
#     min-height: 224px;
#   }
# }
#
# .medicineMainContent {
#   width: 73%;
#   padding: 0;
#   margin-right: 15px;
#   position: relative;
#   @include for-size(phone) {
#     width: 100%;
#     padding: 0;
#   }
# }
#
# .orderContent {
#   width: 27%;
#   @include for-size(phone) {
#     width: 100%;
#   }
# }
# .mmContent {
#   padding: 0 30px;
#   @include for-size(phone) {
#     padding: 0 16px 20px;
#     min-height: 2131px;
#   }
# }
#
# .circleSliderContainer {
#   height: 240px;
#   padding: 20px 0;
#   @include for-size(phone) {
#     height: 185px;
#   }
# }
#
# .specialOfferActionBtn {
#   margin: 0 0 6px 0;
#   > a {
#     padding: 0 15px;
#     @include flex(center, unset, row);
#     cursor: pointer;
#     height: 53px;
#     & > span {
#       display: inline-block;
#       margin-right: 10px;
#       font-size: 32px;
#       padding: 0;
#     }
#     > p {
#       margin: 0;
#       font-size: 14px;
#       @include font-weight(400);
#       text-transform: capitalize;
#     }
#   }
#   @include for-size(phone) {
#     display: none;
#   }
# }
#
# .xsImage {
#   max-width: 400px;
#   margin: 0 auto;
#   height: auto;
# }
#
# .pr {
#   position: relative;
#   z-index: 1;
# }
#
# .bannerPlaceholder {
#   height: 180px;
#   margin: 6px 0;
#   border-radius: 10px !important;
#   @include for-size(phone) {
#     height: 140px;
#   }
# }
# .modalBody {
#   max-height: calc(100vh - 200px);
#   overflow-y: auto;
#   margin-bottom: 10px;
#   padding-bottom: 50px;
# }
# .icon-ic_accordion_down:before {
#   content: "\e949";
#   color: #02475b;
# }
# .icon-ic_arrow_right:before {
#   content: "\ea92";
#   color: #02475b;
# }
# .icon-heartfilled:before {
#   content: "\eb7d";
#   color: #890000;
# }
#
# .icon-notificationOff:before {
#   content: "\eb7e";
#   color: #02475b;
# }
#
# .grid,
# .banner {
#   height: 110px;
#   width: 100%;
#   display: flex;
#   justify-content: center;
#   align-items: center;
#   margin-bottom: 44px;
#   border-bottom: 1px solid black;
# }
# .cartIcon {
#   font-size: 36px !important;
# }
#
# .shimmerWrap {
#   @include for-size(phone) {
#     > div {
#       margin-bottom: 32px;
#     }
#   }
#   @include for-size(desktop) {
#     > div {
#       margin-bottom: 56px;
#     }
#   }
# }
#
# .initialGridStyle {
#   > div {
#     display: flex;
#     width: 100%;
#   }
# }
#   </style>
#   <script type="application/ld+json">
#    {"@context":"https://schema.org","@type":"MedicalOrganization","name":"ApolloPharmacy","alternateName":"Apollo","url":"https://www.apollopharmacy.in","logo":"https://images.apollo247.in/images/apollopharmacy/logo.svg","sameAs":["https://www.facebook.com/ApolloPharmacy","https://twitter.com/ApolloPharmacy","https://www.youtube.com/channel/UCcu5m4OXFqKCqL2HaYREhcg","https://www.linkedin.com/in/apollo-pharmacy-b72bb2106","https://www.apollopharmacy.in/"]}
#   </script>
#   <script async="">
#    (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
#           new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
#           j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
#           'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
#           })(window,document,'script','dataLayer',"GTM-54ZM42J2");
#   </script>
#   <script nomodule="" src="https://www.apollopharmacy.in/assets/production/aph-pharmacy-frontend/_next/static/chunks/polyfills-c67a75d1b6f99dc8.js">
#   </script>
#  </head>
#  <body>
#   <div class="appHeader">
#    <div class="jh">
#     <div class="kh nh">
#      <span class="icon-ic_loginback lh">
#      </span>
#      <span aria-label="logo" class="ph" role="button">
#       <img alt="logo" class="Qh" fetchpriority="low" height="44" loading="lazy" src="https://images.apollo247.in/images/pharmacy_logo.svg?tr=w-125,q-100,f-webp,c-at_max" width="50"/>
#      </span>
#     </div>
#     <div class="kh qh">
#      <span class="icon-searchIcon lh">
#      </span>
#      <span class="icon-cart_icon lh">
#       <i class="rh">
#        0
#       </i>
#      </span>
#     </div>
#    </div>
#   </div>
#   <section>
#    <script class="structured-data-list" type="application/ld+json">
#     {"@context":"https://schema.org/","@type":"Product","name":"Benadryl Cough Formula Syrup, 450 ml","sku":"BEN0005","image":"https://images.apollo247.in/pub/media[object Object]","alternateName":"Benadryl Cough Formula Syrup, 450 ml","brand":{"@type":"brand","logo":""},"manufacturer":{"@type":"MedicalOrganization","name":"Johnson & Johnson Pvt Ltd"},"itemCondition":"NewCondition","description":"&amp;nbsp;&lt;p&gt;&lt;strong&gt;Marketer Address:&lt;/strong&gt; Corporate Communications, Johnson &amp; Johnson Private Limited., 501 Arena Space, Behind Majas Bus Depot, Off Jogeshwari Vikhroli Link Road, Jogeshwari (E), Mumbai 400 060&lt;/p&gt;&lt;p&gt;&lt;strong&gt;Expires on or after: &lt;/strong&gt;Jan-25&lt;/p&gt;","offers":{"@type":"Offer","availability":"http://schema.org/InStock","acceptedPaymentMethod":"COD, Card, Paytm, UPI","addOn":"","advanceBookingRequirement":"","areaServed":"","priceCurrency":"INR","availabilityEnds":"","availabilityStarts":"","availableAtOrFrom":"","availableDeliveryMethod":"Home Delivery","deliveryLeadTime":"","eligibleCustomerType":"","eligibleDuration":"","eligibleQuantity":10,"eligibleRegion":"","eligibleTransactionVolume":"","itemCondition":"NewCondition","ineligibleRegion":"","price":234.7,"seller":"APOLLO HOSPITALS ENTERPRISES LTD","serialNumber":"","validFrom":"","validThrough":"","warranty":"","priceValidUntil":"2020-12-31","url":"https://www.apollopharmacy.in/medicine/benadryl-cough-formula-syrup-450ml"},"category":{"@type":"Thing","image":"https://images.apollo247.in/pub/media[object Object]"},"gtin8":53743,"isSimilarTo":""}
#    </script>
#    <script class="structured-data-list" type="application/ld+json">
#     {"@context":"https://schema.org/","@type":"Drug","name":"Benadryl Cough Formula Syrup, 450 ml","mainEntityOfPage":"https://www.apollopharmacy.in/medicine/benadryl-cough-formula-syrup-450ml","image":"https://images.apollo247.in/pub/media[object Object]","description":"&amp;nbsp;&lt;p&gt;&lt;strong&gt;Marketer Address:&lt;/strong&gt; Corporate Communications, Johnson &amp; Johnson Private Limited., 501 Arena Space, Behind Majas Bus Depot, Off Jogeshwari Vikhroli Link Road, Jogeshwari (E), Mumbai 400 060&lt;/p&gt;&lt;p&gt;&lt;strong&gt;Expires on or after: &lt;/strong&gt;Jan-25&lt;/p&gt;","activeIngredient":"AMMONIUM CHLORIDE+ DIPHENHYDRAMINE HYDROCHLORIDE+ ETHANOL+ SODIUM CITRATE-138+ 14.08+ 0.2625+ 57.03MG+ MG+ ML+ MG","alcoholWarning":"","availableStrength":{"@context":"http://schema.org/","@type":"DrugStrength","activeIngredient":"AMMONIUM CHLORIDE+ DIPHENHYDRAMINE HYDROCHLORIDE+ ETHANOL+ SODIUM CITRATE-138+ 14.08+ 0.2625+ 57.03MG+ MG+ ML+ MG"},"breastfeedingWarning":"","pregnancyWarning":"","clinicalPharmacology":"","dosageForm":"Syrup","drugUnit":"MG+ MG+ ML+ MG","foodWarning":"","isAvailableGenerically":"True","legalStatus":"country: india, status: Approved","overdosage":"","manufacturer":{"@type":"MedicalOrganization","legalName":"Johnson & Johnson Pvt Ltd"},"mechanismOfAction":"","nonProprietaryName":"Benadryl Cough Formula Syrup, 450 ml","isProprietary":true,"prescriptionStatus":"Available by prescription","url":"https://www.apollopharmacy.in/medicine/benadryl-cough-formula-syrup-450ml"}
#    </script>
#    <script class="structured-data-list" type="application/ld+json">
#     {"@context":"https://schema.org","@type":"FAQPage","name":"Benadryl Cough Formula Syrup, 450 ml","mainEntity":[{"@type":"Question","name":"How does Benadryl Cough Formula Syrup, 450 ml work?","acceptedAnswer":{"@type":"Answer","text":"Benadryl Cough Formula Syrup, 450 ml contains Ammonium chloride, Diphenhydramine hydrochloride, Sodium citrate and ethanol. Ammonium chloride increases the volume of fluid in the airways, reduces the stickiness of mucus and helps to remove it from airways. Diphenhydramine hydrochloride blocks the action of histamine, a substance responsible for causing allergic reactions. Sodium citrate works by thinning and loosening phlegm (mucus) in the lungs, windpipe and nose. Thereby, helps to cough out easily. Ethanol is a preservative."}},{"@type":"Question","name":"Does Benadryl Cough Formula Syrup, 450 ml cause dry mouth?","acceptedAnswer":{"@type":"Answer","text":"Benadryl Cough Formula Syrup, 450 ml may cause dry mouth as a temporary side effect in some people. It is not necessary for everyone taking Benadryl Cough Formula Syrup, 450 ml to experience this side effect. However, to avoid such side effects, drink plenty of water, regularly rinse your mouth, practice good oral hygiene and suck on sugarless candy. However, if the condition persists or worsens, please consult a doctor."}},{"@type":"Question","name":"Does Benadryl Cough Formula Syrup, 450 ml cause drowsiness?","acceptedAnswer":{"@type":"Answer","text":"Benadryl Cough Formula Syrup, 450 ml may cause drowsiness or dizziness. It is not necessary for everyone taking Benadryl Cough Formula Syrup, 450 ml to experience this side effect. However, avoid driving if you feel drowsy or dizzy after taking Benadryl Cough Formula Syrup, 450 ml."}},{"@type":"Question","name":"How long should I take Benadryl Cough Formula Syrup, 450 ml?","acceptedAnswer":{"@type":"Answer","text":"You are recommended to take Benadryl Cough Formula Syrup, 450 ml for as long as your doctor has prescribed it. However, if the symptoms persist or worsen with rash, fever or persistent headache after 1 week of using Benadryl Cough Formula Syrup, 450 ml, please consult your doctor."}},{"@type":"Question","name":"Can I stop taking Benadryl Cough Formula Syrup, 450 ml on my own?","acceptedAnswer":{"@type":"Answer","text":"You are not recommended to stop taking Benadryl Cough Formula Syrup, 450 ml without consulting your doctor as it may worsen cough or cause recurring symptoms. Therefore, take Benadryl Cough Formula Syrup, 450 ml for as long as your doctor has prescribed it and if you experience any difficulty while taking Benadryl Cough Formula Syrup, 450 ml, please consult your doctor."}}]}
#    </script>
#    <script class="structured-data-list" type="application/ld+json">
#     {"@type":"BreadcrumbList","@context":"https://schema.org","name":"ApolloPharmacy","itemListElement":[{"@type":"ListItem","position":1,"name":"Home","item":"https://www.apollopharmacy.in"},{"@type":"ListItem","position":2,"name":"Product details of Benadryl Cough Formula Syrup, 450 ml","item":"https://www.apollopharmacy.in/medicine/benadryl-cough-formula-syrup-450ml"}]}
#    </script>
#   </section>
#   <div class="Pdp_wrapper__ykgdU">
#    <div class="RecentlyPurchase_lastBoughtSection__TiK4Z PdpMobile_socialProofing__jq_4u">
#     <span class="icon-graph_up RecentlyPurchase_statIcon__er2rV">
#     </span>
#     Introducing Our Latest Arrival!
#    </div>
#    <div class="PdpMobile_pdpMobileRoot__udGV6">
#     <span class="PdpMobile_topSticky__T68xO">
#      <div class="Nn PdpMobile_hideSticky__CIp78">
#       <div class="On">
#        <img alt="Benadryl Cough Formula Syrup, 450 ml" class="Qh" fetchpriority="low" height="45" loading="lazy" src="https://images.apollo247.in/pub/media/catalog/product/b/e/ben0005_1_1.jpg?tr=w-112.5,q-100,f-webp,c-at_max" width="45"/>
#       </div>
#       <div class="Pn">
#        <h2 class="ub sb Qn">
#         Benadryl Cough Formula Syrup, 450 ml
#        </h2>
#        <div class="EJ Rn">
#         <p class="zb sb GJ Sn Fb">
#          ₹234.7
#         </p>
#         <p class="zb sb HJ Tn JJ Lb">
#          MRP ₹276
#         </p>
#         <p class="zb sb IJ Un">
#          15 % off
#         </p>
#        </div>
#       </div>
#      </div>
#     </span>
#     <div class="BannerSection_bannerSectionDefault__TWrff dynamic_section" id="PDP title banner Mweb">
#      <div>
#       <div class="OJ">
#        <h1 class="tb sb PJ">
#         Benadryl Cough Formula Syrup, 450 ml
#        </h1>
#        <span class="icon-Share QJ">
#        </span>
#       </div>
#      </div>
#     </div>
#     <div class="BannerSection_bannerSectionDefault__TWrff dynamic_section" id="Best Seller Tag Mweb">
#      <div>
#       <div class="HT">
#        <div class="in wn rn Dn jn IT Fn" style="font-weight:500;border-radius:0;padding:undefined;filter:grayscale(1)">
#         Prescription drug
#         <div class="xn zn Cn">
#          <img alt=" Trailing icon" class="Qh" fetchpriority="low" height="20" loading="lazy" src="https://images.apollo247.in/images/ui_revamp_infoIcon.svg?tr=w-50,q-100,f-webp,c-at_max" width="20"/>
#         </div>
#        </div>
#       </div>
#      </div>
#     </div>
#     <div class="Carousel_sliderContainer__ZS918 dynamic_section" id="Pdp product image Mweb">
#      <div class="Carousel_customSliderRoot__PvEHP">
#       <div class="initialKeenStyle initialPdpStyle Carousel_pdpProductImage__HNRvI null">
#        <div class="keen-slider__slide lazy__slide">
#         <div class="Yh">
#          <img alt="Benadryl Cough Formula Syrup, 450 ml, Pack of 1 Syrup" height="164" src="https://images.apollo247.in/pub/media/catalog/product/b/e/ben0005_1_1.jpg?tr=w-164,q-80,f-webp,dpr-false,c-at_max" width="164"/>
#         </div>
#        </div>
#        <div class="keen-slider__slide lazy__slide">
#         <div class="Yh">
#          <img alt="Benadryl Cough Formula Syrup, 450 ml, Pack of 1 Syrup" height="164" src="https://images.apollo247.in/pub/media/catalog/product/b/e/ben0005_2.jpg?tr=w-164,q-80,f-webp,dpr-false,c-at_max" width="164"/>
#         </div>
#        </div>
#        <div class="keen-slider__slide lazy__slide">
#         <div class="Yh">
#          <img alt="Benadryl Cough Formula Syrup, 450 ml, Pack of 1 Syrup" height="164" src="https://images.apollo247.in/pub/media/catalog/product/b/e/ben0005_3.jpg?tr=w-164,q-80,f-webp,dpr-false,c-at_max" width="164"/>
#         </div>
#        </div>
#       </div>
#      </div>
#      <div class="RenderCarosuelThumbnail_thumbnail__QaCaB thumbnailforCarosuel pdpThumbShimmer RenderCarosuelThumbnail_minHeightForThumbnail__OytG_">
#       <div class="keen-slider__slide lazy__slide RenderCarosuelThumbnail_thumbnailCards__4xxuW">
#        <img alt="Online Doctor Consultation &amp; Medicines" class="Qh RenderCarosuelThumbnail_thumbnailImage__0yFCN" fetchpriority="low" height="67" loading="lazy" src="https://images.apollo247.in/pub/media/catalog/product/b/e/ben0005_1_1.jpg?tr=w-167.5,q-100,f-webp,c-at_max" width="67"/>
#       </div>
#       <div class="keen-slider__slide lazy__slide RenderCarosuelThumbnail_thumbnailCards__4xxuW">
#        <img alt="Online Doctor Consultation &amp; Medicines" class="Qh RenderCarosuelThumbnail_thumbnailImage__0yFCN" fetchpriority="low" height="67" loading="lazy" src="https://images.apollo247.in/pub/media/catalog/product/b/e/ben0005_2.jpg?tr=w-167.5,q-100,f-webp,c-at_max" width="67"/>
#       </div>
#       <div class="keen-slider__slide lazy__slide RenderCarosuelThumbnail_thumbnailCards__4xxuW">
#        <img alt="Online Doctor Consultation &amp; Medicines" class="Qh RenderCarosuelThumbnail_thumbnailImage__0yFCN" fetchpriority="low" height="67" loading="lazy" src="https://images.apollo247.in/pub/media/catalog/product/b/e/ben0005_3.jpg?tr=w-167.5,q-100,f-webp,c-at_max" width="67"/>
#       </div>
#      </div>
#     </div>
#     <div class="BannerSection_bannerSectionDefault__TWrff dynamic_section" id="Express Delivery Tag Mweb">
#      <div>
#      </div>
#     </div>
#     <div class="BannerSection_bannerSectionDefault__TWrff dynamic_section" id="PDP multivariant banner Mweb">
#      <div>
#       <div class="GP">
#       </div>
#      </div>
#     </div>
#     <div class="BannerSection_bannerSectionDefault__TWrff dynamic_section" id="PDP price banner Mweb">
#      <div>
#       <div class="_N yN">
#        <div class="aN">
#         <span class="bN">
#          MRP:
#         </span>
#        </div>
#        <div class="DL oN">
#         <p class="EL">
#         </p>
#        </div>
#        <div class="OL WL vN wN">
#         <img alt="circle image" class="Qh" fetchpriority="low" height="15" loading="lazy" src="https://images.apollo247.in/images/ic-circleLogo.svg?tr=w-60,q-100,f-webp,c-at_max" width="24"/>
#         <div class="PL TL">
#          <p class="zb sb VL">
#           JOIN to get FREE Delivery
#          </p>
#          <button aria-label="Know More" class="uf XL Mf">
#           <span>
#            Know More
#           </span>
#          </button>
#         </div>
#        </div>
#       </div>
#      </div>
#     </div>
#     <div class="BannerSection_bannerSectionDefault__TWrff dynamic_section" id="PDP address banner Mweb">
#      <div>
#       <div class="lP">
#        <div class="mP">
#         <div class="nP">
#          <span class="pP icon-Vector">
#          </span>
#          <div class="rP">
#           <input class="wP" placeholder="Enter delivery pincode" type="text" value=""/>
#          </div>
#          <button aria-label="Change" class="uf xP Ef">
#           <span>
#            Apply
#           </span>
#          </button>
#         </div>
#        </div>
#        <div class="AP">
#         <div class="zP">
#          <span class="yP icon-address_icon">
#          </span>
#          <p class="zb sb sP">
#           Provide Delivery Location
#          </p>
#         </div>
#        </div>
#       </div>
#      </div>
#     </div>
#     <div class="BannerSection_bannerSectionDefault__TWrff dynamic_section" id="PDP bmsm banner Mweb">
#      <div>
#       <div class="tR">
#        <div class="uR">
#        </div>
#       </div>
#      </div>
#     </div>
#     <div class="Carousel_sliderContainer__ZS918 dynamic_section" id="Extra Savings Mweb">
#      <div class="sectionTop">
#       <h2 class="sectionHeading">
#        Extra Savings
#       </h2>
#      </div>
#      <div class="Carousel_customSliderRoot__PvEHP">
#       <div class="initialKeenStyle initialBannerStyle Carousel_bannerStyle__5QYEx null">
#        <div class="keen-slider__slide lazy__slide">
#         <div class="Uh">
#          <a aria-label="Banner" class="Vh" href="https://www.apollopharmacy.in/shop-by-category/cerave">
#           <img alt="Banner" class="Qh Wh" fetchpriority="low" height="200" loading="lazy" src="https://images.apollo247.in/pub/media/magestore/bannerslider/images/c/e/cerave_banner_pdp_1.jpg?tr=w-400,q-100,f-webp,c-at_max" width="400"/>
#          </a>
#         </div>
#        </div>
#        <div class="keen-slider__slide lazy__slide">
#         <div class="Uh">
#          <a aria-label="Banner" class="Vh" href="https://www.apollopharmacy.in/shop-by-category/proteins1">
#           <img alt="Banner" class="Qh Wh" fetchpriority="low" height="200" loading="lazy" src="https://images.apollo247.in/pub/media/magestore/bannerslider/images/p/r/protein_powders.jpg?tr=w-400,q-100,f-webp,c-at_max" width="400"/>
#          </a>
#         </div>
#        </div>
#        <div class="keen-slider__slide lazy__slide">
#         <div class="Uh">
#          <a aria-label="Banner" class="Vh" href="https://www.apollopharmacy.in/shop-by-brand/holland-and-barrett">
#           <img alt="Banner" class="Qh Wh" fetchpriority="low" height="200" loading="lazy" src="https://images.apollo247.in/pub/media/magestore/bannerslider/images/h/n/hnb_banner.jpg?tr=w-400,q-100,f-webp,c-at_max" width="400"/>
#          </a>
#         </div>
#        </div>
#        <div class="keen-slider__slide lazy__slide">
#         <div class="Uh">
#          <a aria-label="Banner" class="Vh" href="https://www.apollo247.com/lab-tests">
#           <img alt="Banner" class="Qh Wh" fetchpriority="low" height="200" loading="lazy" src="https://images.apollo247.in/pub/media/magestore/bannerslider/images/m/i/microsoftteams-image_62__2.png?tr=w-400,q-100,f-webp,c-at_max" width="400"/>
#          </a>
#         </div>
#        </div>
#        <div class="keen-slider__slide lazy__slide">
#         <div class="Uh">
#          <a aria-label="Banner" class="Vh" href="https://www.apollo247.com/insurance?utm_source=HANA_Insurance&amp;utm_medium=Banner&amp;utm_campaign=insurance_2banner">
#           <img alt="Banner" class="Qh Wh" fetchpriority="low" height="200" loading="lazy" src="https://images.apollo247.in/pub/media/magestore/bannerslider/images/i/n/insurance_banner_1.jpg?tr=w-400,q-100,f-webp,c-at_max" width="400"/>
#          </a>
#         </div>
#        </div>
#       </div>
#      </div>
#      <div class="dots">
#       <button aria-label="carousel dot" class="RenderCarosuelDots_dot__FZjx7 RenderCarosuelDots_active__ufvr7">
#       </button>
#      </div>
#     </div>
#     <div class="BannerSection_bannerSectionDefault__TWrff dynamic_section" id="PDP widget banner Mweb">
#      <div>
#       <div class="VJ">
#        <div class="WJ">
#         <img alt="Secure Payment icon" class="Qh XJ" fetchpriority="low" height="64" loading="lazy" src="https://images.apollo247.in/images/ui_revamp_secure_payment_widget.svg?tr=w-160,q-100,f-webp,c-at_max" width="64"/>
#         <h2 class="ub sb YJ">
#          Secure Payment
#         </h2>
#        </div>
#        <div class="WJ">
#         <img alt="Trusted by 8 Crore Indians icon" class="Qh XJ" fetchpriority="low" height="64" loading="lazy" src="https://images.apollo247.in/images/ui_revamp_fullyreliable_widget.svg?tr=w-160,q-100,f-webp,c-at_max" width="64"/>
#         <h2 class="ub sb YJ">
#          Trusted by 8 Crore Indians
#         </h2>
#        </div>
#        <div class="WJ">
#         <img alt="Genuine Products icon" class="Qh XJ" fetchpriority="low" height="64" loading="lazy" src="https://images.apollo247.in/images/ui_revamp_genuineProducts_widget.svg?tr=w-160,q-100,f-webp,c-at_max" width="64"/>
#         <h2 class="ub sb YJ">
#          Genuine Products
#         </h2>
#        </div>
#       </div>
#       <div class="ZJ">
#       </div>
#      </div>
#     </div>
#     <div class="GridSection_gridMainSection__vBvkP GridSection_gridGapZero__xL6q_ initialGridStyle dynamic_section" id="PDP Product Main Info">
#      <div class="Grid_grid__sFg6e" style="grid-template-columns:repeat( auto-fit, minmax(calc(100% / 1 - 16px), 1fr) );grid-column-gap:16px;grid-row-gap:16px">
#       <div class="Grid_Item__KaQ4v">
#        <div class="eP">
#         <div>
#          <h2 class="ub sb fP">
#           Composition
#          </h2>
#          <a aria-label="AMMONIUM CHLORIDE-138MG + DIPHENHYDRAMINE HYDROCHLORIDE-14.08MG + ETHANOL-0.2625ML + SODIUM CITRATE-57.03MG" class="cardAnchorStyle" href="/salt/AMMONIUM CHLORIDE+DIPHENHYDRAMINE HYDROCHLORIDE+ETHANOL+SODIUM CITRATE">
#           <div class="iP jP">
#            AMMONIUM CHLORIDE-138MG + DIPHENHYDRAMINE HYDROCHLORIDE-14.08MG + ETHANOL-0.2625ML + SODIUM CITRATE-57.03MG
#           </div>
#          </a>
#         </div>
#        </div>
#       </div>
#       <div class="Grid_Item__KaQ4v">
#        <div class="eP">
#         <div>
#          <h2 class="ub sb fP">
#           Manufacturer/Marketer
#          </h2>
#          <div class="iP">
#           Johnson &amp; Johnson Pvt Ltd
#          </div>
#         </div>
#        </div>
#       </div>
#       <div class="Grid_Item__KaQ4v">
#        <div class="eP">
#         <div>
#          <h2 class="ub sb fP">
#           Consume Type
#          </h2>
#          <div class="iP">
#           ORAL
#          </div>
#         </div>
#        </div>
#       </div>
#       <div class="Grid_Item__KaQ4v">
#        <div class="eP">
#         <div>
#          <h2 class="ub sb fP">
#           Return Policy
#          </h2>
#          <div class="iP">
#           Not Returnable
#          </div>
#         </div>
#        </div>
#       </div>
#       <div class="Grid_Item__KaQ4v">
#        <div class="eP">
#         <div>
#          <h2 class="ub sb fP">
#           Expires on or after
#          </h2>
#          <div class="iP">
#           Jan-25
#          </div>
#         </div>
#        </div>
#       </div>
#      </div>
#     </div>
#     <div class="BannerSection_bannerSectionDefault__TWrff dynamic_section" id="PDP Product Details Mweb">
#      <div>
#       <div class="zV">
#        <div class="AV">
#         <input checked="" id="checkboxAccordionPDP0" name="accordionAccordionPDP" type="checkbox"/>
#         <label aria-label="Product Details" class="BV" for="checkboxAccordionPDP0" role="button">
#          <span class="CV">
#           Product Details
#          </span>
#          <span class="DV EV">
#          </span>
#         </label>
#         <div aria-label="Panel Details" class="HV">
#          <div class="eP">
#           <div>
#            <h2 class="ub sb fP">
#             About Benadryl Cough Formula Syrup, 450 ml
#            </h2>
#            <div class="iP">
#             <p class="MsoNormal" style="margin-top:6.0pt;margin-right:0cm;margin-bottom:6.0pt;margin-left:0cm;text-align:justify;line-height:150%">
#              Benadryl Cough Formula Syrup, 450 ml belongs to a class of medications called ‘expectorants’ used to treat cough. Coughing (dry or productive) is the body’s way of clearing irritants (like allergens, mucus, or smoke) from airways and preventing infection. There are two types of coughs, namely: Dry cough and chesty cough. A dry cough is tickly and doesn't produce any vicious or thick mucus, while a chesty cough (wet cough) means mucous or sputum is produced to help clear your airways.
#             </p>
#             <p class="MsoNormal" style="margin-top:6.0pt;margin-right:0cm;margin-bottom:6.0pt;margin-left:0cm;text-align:justify;line-height:150%">
#              Benadryl Cough Formula Syrup, 450 ml is a combination of four drugs, namely: Ammonium chloride (expectorants), Diphenhydramine hydrochloride (antihistamine), Sodium citrate (mucolytic), and ethanol. Ammonium chloride works by increasing the volume of fluid in the airways, reducing the stickiness of mucus. Diphenhydramine hydrochloride works by blocking the action of histamine, a substance responsible for causing allergic reactions. Sodium citrate works by thinning and loosening phlegm (mucus) in the lungs, windpipe, and nose. Thereby, it helps to cough out easily. Ethanol acts as a preservative.
#             </p>
#             <p class="MsoNormal" style="margin-top:6.0pt;margin-right:0cm;margin-bottom:6.0pt;margin-left:0cm;text-align:justify;line-height:150%">
#              Take Benadryl Cough Formula Syrup, 450 ml as prescribed by your doctor. You are advised to take Benadryl Cough Formula Syrup, 450 ml for as long as your doctor has prescribed it for you based on your medical condition. In some cases, you may experience drowsiness, dizziness, dry mouth, nervousness, stomach pain, diarrhoea, or constipation. Most of these side effects of Benadryl Cough Formula Syrup, 450 ml do not require medical attention and gradually resolve over time. However, if the side effects persist or worsen, please consult your doctor.
#             </p>
#             <p class="MsoNormal" style="margin-top:6.0pt;margin-right:0cm;margin-bottom:6.0pt;margin-left:0cm;text-align:justify;line-height:150%">
#              If you are allergic to Benadryl Cough Formula Syrup, 450 ml or any other medicines, please tell your doctor. Benadryl Cough Formula Syrup, 450 ml is not recommended for children below 2 years of age unless advised by a doctor. If you are pregnant or breastfeeding, it is advised to inform your doctor before using Benadryl Cough Formula Syrup, 450 ml. Benadryl Cough Formula Syrup, 450 ml should be used with caution in elderly patients due to the increased risk of side effects. Drive only if you are alert as Benadryl Cough Formula Syrup, 450 ml may cause dizziness. You are recommended to avoid alcohol consumption with Benadryl Cough Formula Syrup, 450 ml as it may increase drowsiness or dizziness.
#              <span style='font-size:12.0pt;line-height:150%;font-family:"Times New Roman",serif;color:black;mso-themecolor:text1'>
#               <o:p>
#               </o:p>
#              </span>
#             </p>
#            </div>
#           </div>
#          </div>
#          <div class="eP">
#           <div>
#            <h2 class="ub sb fP">
#             Uses of Benadryl Cough Formula Syrup, 450 ml
#            </h2>
#            <div class="iP">
#             <p class="MsoNormal" style="margin-bottom:0cm;margin-bottom:.0001pt;text-align:justify;line-height:150%">
#              Cough
#              <span style='font-size:12.0pt;line-height:150%;font-family:"Times New Roman",serif;mso-fareast-font-family:"Times New Roman";color:black;mso-themecolor:text1;mso-fareast-language:EN-IN'>
#               <o:p>
#               </o:p>
#              </span>
#             </p>
#            </div>
#           </div>
#          </div>
#          <div class="eP">
#           <div>
#            <h2 class="ub sb fP">
#             Medicinal Benefits
#            </h2>
#            <div class="iP">
#             <p class="MsoNormal" style="text-align:justify;line-height:150%">
#              Benadryl Cough Formula Syrup, 450 ml contains Ammonium chloride, Diphenhydramine hydrochloride, Sodium citrate and ethanol used to treat cough. Ammonium chloride is an expectorant that increases the volume of fluid in the airways, reduces the stickiness of mucus and helps to remove it from the airways. Diphenhydramine hydrochloride is an antihistamine (anti-allergic drug) that blocks the action of histamine, a substance responsible for causing allergic reactions.  It helps to provide relief from symptoms of allergy such as sneezing, running nose, watery eyes, itching, swelling, and congestion or stiffness. Sodium citrate is a mucolytic agent (cough/sputum thinner) that works by thinning and loosening phlegm (mucus) in the lungs, windpipe and nose. Thereby, it helps to cough out easily. Ethanol acts as a preservative.
#             </p>
#            </div>
#           </div>
#          </div>
#          <div class="eP">
#           <div>
#            <h2 class="ub sb fP">
#             Directions for Use
#            </h2>
#            <div class="iP">
#             Take Benadryl Cough Formula Syrup, 450 ml with or without food as advised by your doctor. Shake the bottle well before use. Take the prescribed dose by mouth using the measuring cup/dosing syringe/dropper provided by the pack.
#            </div>
#           </div>
#          </div>
#          <div class="eP">
#           <div>
#            <h2 class="ub sb fP">
#             Storage
#            </h2>
#            <div class="iP">
#             Store in a cool and dry place away from sunlight
#            </div>
#           </div>
#          </div>
#          <div class="eP">
#           <div>
#            <h2 class="ub sb fP">
#             Side Effects of Benadryl Cough Formula Syrup, 450 ml
#            </h2>
#            <div class="iP">
#             <ul>
#              <li>
#               Drowsiness
#              </li>
#              <li>
#               Dizziness
#              </li>
#              <li>
#               Dry mouth
#              </li>
#              <li>
#               Nervousness
#              </li>
#              <li>
#               Stomach pain
#              </li>
#              <li>
#               Diarrhoea
#              </li>
#              <li>
#               Constipation
#              </li>
#             </ul>
#            </div>
#           </div>
#          </div>
#         </div>
#        </div>
#        <div class="AV">
#         <input checked="" id="checkboxAccordionPDP1" name="accordionAccordionPDP" type="checkbox"/>
#         <label aria-label="In-depth Information" class="BV" for="checkboxAccordionPDP1" role="button">
#          <span class="CV">
#           In-depth Information
#          </span>
#          <span class="DV EV">
#          </span>
#         </label>
#         <div aria-label="Panel Details" class="HV">
#          <div class="eP">
#           <div>
#            <h2 class="ub sb fP">
#             Drug Warnings
#            </h2>
#            <div class="iP">
#             <p class="text-align-justify">
#              If you are allergic to Benadryl Cough Formula Syrup, 450 ml or any other medicines, please tell your doctor. Benadryl Cough Formula Syrup, 450 ml is not recommended for children below 2 years of age unless advised by a doctor. If you are pregnant or breastfeeding, it is advised to inform your doctor before using Benadryl Cough Formula Syrup, 450 ml. Benadryl Cough Formula Syrup, 450 ml should be used with caution in elderly patients due to increased risk of side effects. Avoid using Benadryl Cough Formula Syrup, 450 ml if you have taken medicines such as linezolid, phenelzine, selegiline, rasagiline, isocarboxazid, tranylcypromine and methylene blue injection in the past 14 days. If you have asthma, inform your doctor before taking Benadryl Cough Formula Syrup, 450 ml. Drive only if you are alert as Benadryl Cough Formula Syrup, 450 ml may cause dizziness. You are recommended to avoid alcohol consumption with Benadryl Cough Formula Syrup, 450 ml as it may increase drowsiness or dizziness.
#             </p>
#            </div>
#           </div>
#          </div>
#          <div class="eP">
#           <div>
#            <h2 class="ub sb fP">
#             Drug Interactions
#            </h2>
#            <div class="iP">
#             <p class="MsoNormal" style="text-align:justify;line-height:150%">
#              <meta content="uuid9PFgsb21oNDs" name="uuid"/>
#              <meta charset="utf-8"/>
#             </p>
#             <p class="text-align-justify">
#              <strong>
#               Drug-Drug Interaction:
#              </strong>
#              Benadryl Cough Formula Syrup, 450 ml may interact with a blood thinner (warfarin), antibiotic (chloramphenicol), medicines containing propantheline or metoclopramide, and anticonvulsants (pregabalin).
#             </p>
#             <p class="text-align-justify">
#              <strong>
#               Drug-Food Interaction:
#              </strong>
#              Benadryl Cough Formula Syrup, 450 ml may interact with alcohol. Therefore, avoid the consumption of alcohol with Benadryl Cough Formula Syrup, 450 ml as it may increase the risk of adverse effects such as drowsiness or dizziness.
#             </p>
#             <p class="text-align-justify">
#              <strong>
#               Drug-Disease Interaction:
#              </strong>
#              If you have asthma, pneumonia, glaucoma, epilepsy, bladder problems (urinary retention), prostate problems, liver or kidney disease, inform your doctor before taking Benadryl Cough Formula Syrup, 450 ml.
#             </p>
#             <p class="MsoNormal" style="text-align:justify;line-height:150%">
#              <span style='font-size:12.0pt;line-height:150%;font-family:"Times New Roman",serif;color:black;mso-themecolor:text1'>
#               <o:p>
#               </o:p>
#              </span>
#             </p>
#            </div>
#           </div>
#          </div>
#          <div class="eP">
#           <div>
#            <h2 class="ub sb fP">
#             Drug-Drug Interactions Checker List
#            </h2>
#            <div class="iP">
#             <ul>
#              <li>
#               <span>
#                WARFARIN
#               </span>
#              </li>
#              <li>
#               <span>
#                CHLORAMPHENICOL
#               </span>
#              </li>
#              <li>
#               <span>
#                PROPANTHELINE
#               </span>
#              </li>
#              <li>
#               <span>
#                METOCLOPRAMIDE
#               </span>
#              </li>
#              <li>
#               <span>
#                PREGABALIN
#               </span>
#              </li>
#             </ul>
#            </div>
#           </div>
#          </div>
#          <div class="eP">
#           <div>
#            <h2 class="ub sb fP">
#             Habit Forming
#            </h2>
#            <div class="iP">
#             No
#            </div>
#           </div>
#          </div>
#          <div class="eP">
#           <div>
#            <h2 class="ub sb fP">
#             Diet &amp; Lifestyle Advise
#            </h2>
#            <div class="iP">
#             <ul>
#              <li class="text-align-justify">
#               Avoid dairy products such as milk as it may increase mucus production. Also, avoid processed or refined foods. Instead replace baked foods, fried foods, white bread, white pasta, french fries, sugary desserts and chips with green leafy vegetables.
#              </li>
#              <li class="text-align-justify">
#               Drink plenty of fluids to avoid dry throat while you have a cough. It also helps loosen mucus.
#              </li>
#              <li class="text-align-justify">
#               Avoid citrus fruits as they may worsen the cough. Eat fruits rich in water content such as pears, watermelon, peaches and pineapples.
#              </li>
#             </ul>
#            </div>
#           </div>
#          </div>
#          <div class="eP">
#           <div>
#            <h2 class="ub sb fP">
#             Special Advise
#            </h2>
#            <div class="iP">
#             <p class="MsoNormal" style="text-align:justify;line-height:150%">
#              If the symptoms persist or worsen after using Benadryl Cough Formula Syrup, 450 ml for 1 week, please consult a doctor.
#             </p>
#            </div>
#           </div>
#          </div>
#         </div>
#        </div>
#        <div class="AV">
#         <input checked="" id="checkboxAccordionPDP2" name="accordionAccordionPDP" type="checkbox"/>
#         <label aria-label="Patients Concern" class="BV" for="checkboxAccordionPDP2" role="button">
#          <span class="CV">
#           Patients Concern
#          </span>
#          <span class="DV EV">
#          </span>
#         </label>
#         <div aria-label="Panel Details" class="HV">
#          <div class="eP">
#           <div>
#            <h2 class="ub sb fP">
#             Disease/Condition Glossary
#            </h2>
#            <div class="iP">
#             <p class="MsoNormal" style="margin-top:6.0pt;margin-right:0cm;margin-bottom:6.0pt;margin-left:0cm;text-align:justify;line-height:150%">
#              <meta content="uuid9PFgsb21oNDs" name="uuid"/>
#              <meta charset="utf-8"/>
#              <strong>
#               Cough:
#              </strong>
#              Coughing is a body’s way of clearing irritants (like allergens, mucus or smoke) from airways and preventing infection. Coughs may be dry or productive. A productive cough (wet cough) brings up sputum (phlegm, mucus and other matter) from the lungs. Cough is commonly caused as a response to allergy or viral infection but coughing up mucus is possibly an indication of infection in the respiratory tract. If you are coughing thick, solid white mucus, it indicates you may have a bacterial infection in the airways. If the mucus is clear or light-coloured, it indicates you may have allergies or minor infection in the respiratory tract and yellow or green mucus indicates a respiratory infection.
#             </p>
#            </div>
# ...
#   </script>
#   <script>
#    self.__next_f.push([1,"15:Tc4d,"])
#   </script>
#   <script>
#    self.__next_f.push([1,"\u0026lt;p class='MsoNormal' style='margin-top:6.0pt;margin-right:0cm;margin-bottom:6.0pt;margin-left:0cm;text-align:justify;line-height:150%'\u0026gt;Benadryl Cough Formula Syrup, 450 ml belongs to a class of medications called ‘expectorants’ used to treat cough. Coughing (dry or productive) is the body’s way of clearing irritants (like allergens, mucus, or smoke) from airways and preventing infection. There are two types of coughs, namely: Dry cough and chesty cough. A dry cough is tickly and doesn't produce any vicious or thick mucus, while a chesty cough (wet cough) means mucous or sputum is produced to help clear your airways.\u0026lt;/p\u0026gt;\u0026lt;p class='MsoNormal' style='margin-top:6.0pt;margin-right:0cm;margin-bottom:6.0pt;margin-left:0cm;text-align:justify;line-height:150%'\u0026gt;Benadryl Cough Formula Syrup, 450 ml is a combination of four drugs, namely: Ammonium chloride (expectorants), Diphenhydramine hydrochloride (antihistamine), Sodium citrate (mucolytic), and ethanol. Ammonium chloride\u0026amp;nbsp;works by increasing the volume of fluid in the airways, reducing the stickiness of mucus. Diphenhydramine hydrochloride works by blocking the action of histamine, a substance responsible for causing allergic reactions. Sodium citrate\u0026amp;nbsp;works by thinning and loosening phlegm (mucus) in the lungs, windpipe, and nose. Thereby, it helps to cough out easily. Ethanol acts as a preservative.\u0026lt;/p\u0026gt;\u0026lt;p class='MsoNormal' style='margin-top:6.0pt;margin-right:0cm;margin-bottom:6.0pt;margin-left:0cm;text-align:justify;line-height:150%'\u0026gt;Take Benadryl Cough Formula Syrup, 450 ml as prescribed by your doctor. You are advised to take Benadryl Cough Formula Syrup, 450 ml for as long as your doctor has prescribed it for you based on your medical condition. In some cases, you may experience drowsiness, dizziness, dry mouth, nervousness, stomach pain, diarrhoea, or constipation. Most of these side effects of Benadryl Cough Formula Syrup, 450 ml do not require medical attention and gradually resolve over time. However, if the side effects persist or worsen, please consult your doctor.\u0026lt;/p\u0026gt;\u0026lt;p class='MsoNormal' style='margin-top:6.0pt;margin-right:0cm;margin-bottom:6.0pt;margin-left:0cm;text-align:justify;line-height:150%'\u0026gt;If you are allergic to Benadryl Cough Formula Syrup, 450 ml or any other medicines, please tell your doctor. Benadryl Cough Formula Syrup, 450 ml is not recommended for children below 2 years of age unless advised by a doctor. If you are pregnant or breastfeeding, it is advised to inform your doctor before using Benadryl Cough Formula Syrup, 450 ml. Benadryl Cough Formula Syrup, 450 ml should be used with caution in elderly patients due to the increased risk of side effects. Drive only if you are alert as Benadryl Cough Formula Syrup, 450 ml may cause dizziness. You are recommended to avoid alcohol consumption with Benadryl Cough Formula Syrup, 450 ml as it may increase drowsiness or dizziness.\u0026lt;span style='font-size:12.0pt;line-height:150%;font-family:\u0026amp;quot;Times New Roman\u0026amp;quot;,serif;color:black;mso-themecolor:text1'\u0026gt; \u0026lt;o:p\u0026gt;\u0026lt;/o:p\u0026gt;\u0026lt;/span\u0026gt;\u0026lt;/p\u0026gt;"])
#   </script>
#   <script>
#    self.__next_f.push([1,"16:T419,"])
#   </script>
#   <script>
#    self.__next_f.push([1,"\u0026lt;p class='text-align-justify'\u0026gt;If you are allergic to Benadryl Cough Formula Syrup, 450 ml or any other medicines, please tell your doctor. Benadryl Cough Formula Syrup, 450 ml is not recommended for children below 2 years of age unless advised by a doctor. If you are pregnant or breastfeeding, it is advised to inform your doctor before using Benadryl Cough Formula Syrup, 450 ml. Benadryl Cough Formula Syrup, 450 ml should be used with caution in elderly patients due to increased risk of side effects. Avoid using Benadryl Cough Formula Syrup, 450 ml if you have taken medicines such as linezolid, phenelzine, selegiline, rasagiline, isocarboxazid, tranylcypromine and methylene blue injection in the past 14 days. If you have asthma, inform your doctor before taking Benadryl Cough Formula Syrup, 450 ml. Drive only if you are alert as Benadryl Cough Formula Syrup, 450 ml may cause dizziness. You are recommended to avoid alcohol consumption with Benadryl Cough Formula Syrup, 450 ml as it may increase drowsiness or dizziness.\u0026lt;/p\u0026gt;"])
#   </script>
#   <script>
#    self.__next_f.push([1,"17:T562,"])
#   </script>
#   <script>
#    self.__next_f.push([1,"\u0026lt;p class='MsoNormal' style='text-align:justify;line-height:150%'\u0026gt;\u0026lt;meta name='uuid' content='uuid9PFgsb21oNDs' /\u0026gt;\u0026lt;meta charset='utf-8' /\u0026gt;\u0026lt;/p\u0026gt;\u0026lt;p class='text-align-justify'\u0026gt;\u0026lt;strong\u0026gt;Drug-Drug Interaction:\u0026amp;nbsp;\u0026lt;/strong\u0026gt;Benadryl Cough Formula Syrup, 450 ml may interact with a blood thinner (warfarin), antibiotic (chloramphenicol), medicines containing propantheline or metoclopramide, and anticonvulsants (pregabalin).\u0026lt;/p\u0026gt;\u0026lt;p class='text-align-justify'\u0026gt;\u0026lt;strong\u0026gt;Drug-Food Interaction:\u0026amp;nbsp;\u0026lt;/strong\u0026gt;Benadryl Cough Formula Syrup, 450 ml may interact with alcohol. Therefore, avoid the consumption of alcohol with Benadryl Cough Formula Syrup, 450 ml as it may increase the risk of adverse effects such as drowsiness or dizziness.\u0026lt;/p\u0026gt;\u0026lt;p class='text-align-justify'\u0026gt;\u0026lt;strong\u0026gt;Drug-Disease Interaction:\u0026lt;/strong\u0026gt;\u0026amp;nbsp;If you have asthma, pneumonia, glaucoma, epilepsy, bladder problems (urinary retention), prostate problems, liver or kidney disease, inform your doctor before taking Benadryl Cough Formula Syrup, 450 ml.\u0026lt;/p\u0026gt;\u0026lt;p class='MsoNormal' style='text-align:justify;line-height:150%'\u0026gt;\u0026lt;span style='font-size:12.0pt;line-height:150%;font-family:\u0026amp;quot;Times New Roman\u0026amp;quot;,serif;color:black;mso-themecolor:text1'\u0026gt;\u0026lt;o:p\u0026gt;\u0026lt;/o:p\u0026gt;\u0026lt;/span\u0026gt;\u0026lt;/p\u0026gt;"])
#   </script>
#   <script>
#    self.__next_f.push([1,"18:T4b3,"])
#   </script>
#   <script>
#    self.__next_f.push([1,"query getSkuInfo($skuInfoInput: SkuInfoInput!) {\n  getSkuInfo(skuInfoInput: $skuInfoInput) {\n    stat\n    previouslyBought\n    pdpPriceInfo {\n      price\n      mrp\n      discount\n      __typename\n    }\n    tatInfo {\n      variantSKUs {\n        autoSelected\n        exist\n        mrp\n        qty\n        sellingPrice\n        sku\n        unitOfMeasurement\n        unitPrice\n        variant_attributes {\n          subVariant\n          variant\n          __typename\n        }\n        __typename\n      }\n      fasterTatVariant {\n        showAfterAtc\n        fasterTatVariants {\n          autoSelected\n          exist\n          mrp\n          pack_size\n          qty\n          sellingPrice\n          sku\n          unitOfMeasurement\n          unitPrice\n          variantSkuTatHours\n          variant_attributes {\n            subVariant\n            variant\n            __typename\n          }\n          __typename\n        }\n        __typename\n      }\n      tatResponse {\n        tat\n        items {\n          qty\n          sku\n          mrp\n          __typename\n        }\n        tatU\n        __typename\n      }\n      showTat\n      message\n      unitPrice\n      packInfo\n      __typename\n    }\n    __typename\n  }\n}"])
#   </script>
#   <script>
#    self.__next_f.push([1,"19:T718f2,"])
#   </script>
#   <script>
#    self.__next_f.push([1,"{\"subscriptions\":{\"cashbacks\":{},\"cashbacksStatus\":\"idle\",\"circlePlans\":{\"ids\":[],\"entities\":{}},\"circlePlanMessageTemplate\":null,\"circlePlanTitleTemplate\":null,\"circlePlansStatus\":\"idle\",\"subscriptionsStatus\":\"idle\",\"circlePlanInCart\":null,\"subscriptionCartDetails\":null,\"isUserCircle\":false,\"userSubscriptions\":null,\"userSubscriptionsUpdated\":false,\"selectedSubPlanId\":\"\",\"isPlanFetched\":false,\"packageIds\":[],\"userSavings\":{\"pharmaSavings\":0,\"consultSavings\":0,\"deliverySavings\":0,\"totalSavings\":0,\"benefits\":[]},\"redirection\":false,\"subscriptionDetailsLoading\":true,\"status\":null,\"membershipDetails\":{\"apolloSubscriptions\":null,\"userSubscriptionId\":null,\"benefits\":[],\"faqs\":[],\"termsAndConditions\":[],\"bannerInfo\":null,\"expiryDate\":null,\"remainingDaysToExpire\":null,\"isCircle\":false,\"logoURL\":null,\"renew\":false,\"active\":false,\"status\":null,\"isUpdated\":false,\"groupPlan\":null}},\"common\":{\"dynamicApiResponses\":{\"pharmaBoughtTogether\":{},\"/v1/home/banner/desktop?section=13\":{\"banners\":[{\"name\":\"CeraVe\",\"status\":\"1\",\"image\":\"/magestore/bannerslider/images/c/e/cerave_banner_pdp_1.jpg\",\"start_time\":\"2023-12-20 22:26:00\",\"end_time\":\"2024-02-28 22:26:00\",\"category_url_key\":\"cerave\",\"category_id\":\"6553\",\"redirect_url\":\"https://www.apollopharmacy.in/shop-by-category/cerave\",\"redirect_url_app\":\"apollopatients://shop-by-category/cerave\"},{\"name\":\"Protein Supplements\",\"status\":\"1\",\"image\":\"/magestore/bannerslider/images/p/r/protein_powders.jpg\",\"start_time\":\"2024-01-30 22:25:00\",\"end_time\":\"2024-02-28 22:26:00\",\"category_url_key\":\"proteins1\",\"category_id\":\"146\",\"redirect_url\":\"https://www.apollopharmacy.in/shop-by-category/proteins1\",\"redirect_url_app\":\"apollopatients://shop-by-category/proteins1\"},{\"name\":\"Holland \u0026 Barrett\",\"status\":\"1\",\"image\":\"/magestore/bannerslider/images/h/n/hnb_banner.jpg\",\"start_time\":\"2024-01-30 22:26:00\",\"end_time\":\"2024-02-28 22:25:00\",\"url\":\"https://www.apollopharmacy.in/shop-by-brand/holland-and-barrett\",\"redirect_url\":\"https://www.apollopharmacy.in/shop-by-brand/holland-and-barrett\",\"redirect_url_app\":\"apollopatients://https://www.apollopharmacy.in/shop-by-brand/holland-and-barrett\"},{\"name\":\"All Good Health Days - Diagnostics [Web]\",\"status\":\"1\",\"image\":\"/magestore/bannerslider/images/m/i/microsoftteams-image_62__2.png\",\"start_time\":\"2024-02-07 05:54:00\",\"end_time\":\"2024-03-31 05:54:00\",\"url\":\"https://www.apollo247.com/lab-tests\",\"redirect_url\":\"https://www.apollo247.com/lab-tests\",\"redirect_url_app\":\"apollopatients://https://www.apollo247.com/lab-tests\"},{\"name\":\"Insurance\",\"status\":\"1\",\"image\":\"/magestore/bannerslider/images/i/n/insurance_banner_1.jpg\",\"start_time\":\"2024-02-07 04:12:00\",\"end_time\":\"2024-12-31 04:12:00\",\"url\":\"https://www.apollo247.com/insurance?utm_source=HANA_Insurance\u0026utm_medium=Banner\u0026utm_campaign=insurance_2banner\",\"redirect_url\":\"https://www.apollo247.com/insurance?utm_source=HANA_Insurance\u0026utm_medium=Banner\u0026utm_campaign=insurance_2banner\",\"redirect_url_app\":\"apollopatients://https://www.apollo247.com/insurance?utm_source=HANA_Insurance\u0026utm_medium=Banner\u0026utm_campaign=insurance_2banner\"}]},\"getSkuInfo\":{\"stat\":\"54 people bought in last 7 days\",\"previouslyBought\":false,\"pdpPriceInfo\":{\"price\":234.7,\"mrp\":276,\"discount\":\"15\",\"__typename\":\"PDPPriceInfoType\"},\"tatInfo\":{\"variantSKUs\":[],\"fasterTatVariant\":null,\"tatResponse\":null,\"showTat\":false,\"message\":\"See on Next Step.\",\"unitPrice\":\"\",\"packInfo\":\"450 ml Syrup\",\"__typename\":\"TatInfo\"},\"__typename\":\"SkuInfoResult\"},\"/popcsrchprdsubt_api.php\":{\"product_count\":1,\"products\":[{\"id\":53742,\"sku\":\"BEN0053\",\"is_in_stock\":1,\"status\":\"1\",\"name\":\"Benadryl  ...
#   </script>
#   <script>
#    self.__next_f.push([1,"f:[\"$\",\"$L10\",null,{\"Component\":\"$11\",\"pageProps\":{\"url_key\":\"benadryl-cough-formula-syrup-450ml\",\"productDetails\":{\"productdp\":{\"id\":53743,\"sku\":\"BEN0005\",\"is_returnable\":\"No\",\"is_in_stock\":1,\"status\":\"1\",\"name\":\"Benadryl Cough Formula Syrup, 450 ml\",\"price\":276,\"type_id\":\"Pharma\",\"url_key\":\"benadryl-cough-formula-syrup-450ml\",\"consume_type\":\"Oral\",\"strength\":null,\"key_ingredient\":null,\"size\":null,\"flavour_fragrance\":null,\"variant\":null,\"colour\":null,\"uses\":null,\"pack_size\":\"450\",\"cold_chain_product\":\"No\",\"storage_temp_range\":null,\"banned\":\"No\",\"marketer_address\":\"Corporate Communications, Johnson \u0026 Johnson Private Limited., 501 Arena Space, Behind Majas Bus Depot, Off Jogeshwari Vikhroli Link Road, Jogeshwari (E), Mumbai 400 060\",\"expiry_date\":\"Jan-25\",\"product_information\":\"\",\"key_benefits\":\"\",\"safety_information\":\"\",\"direction_for_use_dosage\":\"\",\"pack_form\":\"Bottle\",\"product_form\":\"Syrup\",\"unit_of_measurement\":\"ml\",\"age\":null,\"gender\":null,\"vegetarian\":null,\"MaxOrderQty\":10,\"sell_online\":1,\"prepaid\":\"No\",\"subcategory\":null,\"image\":[{\"imageUrl\":\"/catalog/product/b/e/ben0005_1_1.jpg\",\"imageAlt\":\"Benadryl Cough Formula Syrup, 450 ml, Pack of 1 Syrup\"},{\"imageUrl\":\"/catalog/product/b/e/ben0005_2.jpg\",\"imageAlt\":\"Benadryl Cough Formula Syrup, 450 ml, Pack of 1 Syrup\"},{\"imageUrl\":\"/catalog/product/b/e/ben0005_3.jpg\",\"imageAlt\":\"Benadryl Cough Formula Syrup, 450 ml, Pack of 1 Syrup\"}],\"thumbnail\":\"/catalog/product/b/e/ben0005_1_1.jpg\",\"small_image\":\"/catalog/product/b/e/ben0005_1_1.jpg\",\"mou\":\"1\",\"manufacturer\":\"Johnson \u0026 Johnson Pvt Ltd\",\"is_prescription_required\":\"1\",\"description\":\"\u0026amp;nbsp;\u0026lt;p\u0026gt;\u0026lt;strong\u0026gt;Marketer Address:\u0026lt;/strong\u0026gt; Corporate Communications, Johnson \u0026amp; Johnson Private Limited., 501 Arena Space, Behind Majas Bus Depot, Off Jogeshwari Vikhroli Link Road, Jogeshwari (E), Mumbai 400 060\u0026lt;/p\u0026gt;\u0026lt;p\u0026gt;\u0026lt;strong\u0026gt;Expires on or after: \u0026lt;/strong\u0026gt;Jan-25\u0026lt;/p\u0026gt;\",\"dc_availability\":\"Yes\",\"is_express\":\"Yes\",\"is_in_contract\":\"Yes\",\"country_of_origin\":\"India\",\"merchandising\":null,\"suggested_qty\":null,\"generic_name\":\"\",\"packer_name\":\"\",\"packer_address\":null,\"importer_name\":\"\",\"importer_address\":null,\"import_date\":null,\"allergen_info\":\"\",\"classifier_1\":\"OTC\",\"classifier_2\":\"COLD \u0026 COUGH\",\"classifier_3\":null,\"vc_restricted\":\"No\",\"merchandising_text\":null,\"is_sensitive\":0,\"moq\":1,\"is_discontinued\":0,\"replacement_sku\":null,\"dosage_forms\":\"Syrup\",\"population\":null,\"dpco_drug\":0,\"schedule_information\":\"G\",\"pharma_product_discount_enable\":0,\"meta_title\":\"Buy BENADRYL COUGH FORMULA SYRUP 450ML - Apollo Pharmacy.\",\"meta_description\":\"Buy Prescribed BENADRYL COUGH FORMULA SYRUP 450ML online at apollopharmacy.in, Know the uses, side effects, price, composition, substitutes, How it works, Precautions and Expert Advice for BENADRYL COUGH FORMULA SYRUP 450ML manufactured by ABBO-ABBOTT IRE\",\"short_name\":\"Benadryl Cough Formula Syrup\",\"disease_name\":null,\"special_price\":234.7,\"redirect_url\":\"/medicine/benadryl-cough-formula-syrup-450ml\",\"redirect_url_app\":\"apollopatients://medicine/benadryl-cough-formula-syrup-450ml\",\"circle_cashback_value\":\"₹12 cashback\",\"circle_cashback_percent\":\"5%\",\"circle_cashback_value_numeric\":12,\"circle_cashback_percent_numeric\":5,\"category_id\":\"239\",\"brand_images\":[],\"multi_variants_products\":{\"attributes\":[{\"label\":\"pack_size\",\"values\":[{\"code\":\"450\",\"label\":\"450\"},{\"code\":\"50\",\"label\":\"50\"},{\"code\":\"150\",\"label\":\"150\"}]}],\"products\":{\"50\":{\"id\":53744,\"sku\":\"BEN0006\",\"is_in_stock\":1,\"name\":\"Benadryl Cough Fo ...
#   </script>
#  </body>
# </html>

# %%
# paras = soup.find_all('p')
# # print(paras)
# for i in paras:
#     print(i)
print(soup.find('div', class_='iP').get_text())
# Out:
# AMMONIUM CHLORIDE-138MG + DIPHENHYDRAMINE HYDROCHLORIDE-14.08MG + ETHANOL-0.2625ML + SODIUM CITRATE-57.03MG

# %%
url  = "https://www.apollopharmacy.in/medicine/benadryl-cough-formula-syrup-450ml"
response = requests.get(url)
if response.status_code == 200:

    print(f"HTML content fetched.")
else:
    print(f"Failed to fetch webpage. Status code: {response.status_code}")

# Step 3: Process fetched data

soup = BeautifulSoup(response.content, 'html.parser')
# Out:
# HTML content fetched.

# %%
content = soup.find('div', class_='zV')#.get_text()
print(content)
# Out:
# <div class="zV"><div class="AV"><input checked="" id="checkboxAccordionPDP0" name="accordionAccordionPDP" type="checkbox"/><label aria-label="Product Details" class="BV" for="checkboxAccordionPDP0" role="button"><span class="CV">Product Details</span><span class="DV EV"></span></label><div aria-label="Panel Details" class="HV"><div class="eP"><div><h2 class="ub sb fP">About Benadryl Cough Formula Syrup, 450 ml</h2><div class="iP"><p class="MsoNormal" style="margin-top:6.0pt;margin-right:0cm;margin-bottom:6.0pt;margin-left:0cm;text-align:justify;line-height:150%">Benadryl Cough Formula Syrup, 450 ml belongs to a class of medications called ‘expectorants’ used to treat cough. Coughing (dry or productive) is the body’s way of clearing irritants (like allergens, mucus, or smoke) from airways and preventing infection. There are two types of coughs, namely: Dry cough and chesty cough. A dry cough is tickly and doesn't produce any vicious or thick mucus, while a chesty cough (wet cough) means mucous or sputum is produced to help clear your airways.</p><p class="MsoNormal" style="margin-top:6.0pt;margin-right:0cm;margin-bottom:6.0pt;margin-left:0cm;text-align:justify;line-height:150%">Benadryl Cough Formula Syrup, 450 ml is a combination of four drugs, namely: Ammonium chloride (expectorants), Diphenhydramine hydrochloride (antihistamine), Sodium citrate (mucolytic), and ethanol. Ammonium chloride works by increasing the volume of fluid in the airways, reducing the stickiness of mucus. Diphenhydramine hydrochloride works by blocking the action of histamine, a substance responsible for causing allergic reactions. Sodium citrate works by thinning and loosening phlegm (mucus) in the lungs, windpipe, and nose. Thereby, it helps to cough out easily. Ethanol acts as a preservative.</p><p class="MsoNormal" style="margin-top:6.0pt;margin-right:0cm;margin-bottom:6.0pt;margin-left:0cm;text-align:justify;line-height:150%">Take Benadryl Cough Formula Syrup, 450 ml as prescribed by your doctor. You are advised to take Benadryl Cough Formula Syrup, 450 ml for as long as your doctor has prescribed it for you based on your medical condition. In some cases, you may experience drowsiness, dizziness, dry mouth, nervousness, stomach pain, diarrhoea, or constipation. Most of these side effects of Benadryl Cough Formula Syrup, 450 ml do not require medical attention and gradually resolve over time. However, if the side effects persist or worsen, please consult your doctor.</p><p class="MsoNormal" style="margin-top:6.0pt;margin-right:0cm;margin-bottom:6.0pt;margin-left:0cm;text-align:justify;line-height:150%">If you are allergic to Benadryl Cough Formula Syrup, 450 ml or any other medicines, please tell your doctor. Benadryl Cough Formula Syrup, 450 ml is not recommended for children below 2 years of age unless advised by a doctor. If you are pregnant or breastfeeding, it is advised to inform your doctor before using Benadryl Cough Formula Syrup, 450 ml. Benadryl Cough Formula Syrup, 450 ml should be used with caution in elderly patients due to the increased risk of side effects. Drive only if you are alert as Benadryl Cough Formula Syrup, 450 ml may cause dizziness. You are recommended to avoid alcohol consumption with Benadryl Cough Formula Syrup, 450 ml as it may increase drowsiness or dizziness.<span style='font-size:12.0pt;line-height:150%;font-family:"Times New Roman",serif;color:black;mso-themecolor:text1'> <o:p></o:p></span></p></div></div></div><div class="eP"><div><h2 class="ub sb fP">Uses of Benadryl Cough Formula Syrup, 450 ml</h2><div class="iP"><p class="MsoNormal" style="margin-bottom:0cm;margin-bottom:.0001pt;text-align:justify;line-height:150%">Cough<span style='font-size:12.0pt;line-height:150%;font-family:"Times New Roman",serif;mso-fareast-font-family:"Times New Roman";color:black;mso-themecolor:text1;mso-fareast-language:EN-IN'> <o:p></o:p></span></p></div></div></div><div class="eP"><div><h2 class="ub sb fP">Medicinal Benefits</h2><div ...

# %%
# Function to extract section from webpage
def extract_section(soup, class_name):
    section = soup.find(class_= class_name)
    if section:
        return section.text.strip()
    return  


introduction = extract_section(soup, 'OJ')
print(introduction)
about = extract_section(soup, 'iP')
print(about)
# Out:
# Benadryl Cough Formula Syrup, 450 ml
# AMMONIUM CHLORIDE-138MG + DIPHENHYDRAMINE HYDROCHLORIDE-14.08MG + ETHANOL-0.2625ML + SODIUM CITRATE-57.03MG

# %%
About = ['\n'.join(p.text for p in soup.find('div', class_='iP').find_all('p') if 'About' in p.text)]
print(About)
# Out:
# ['']

# %%
import csv
import requests
from bs4 import BeautifulSoup
from csv import DictWriter



netmed_responses = []

# Step 2: Fetch data from each URL
url  = "https://www.apollopharmacy.in/medicine/benadryl-cough-formula-syrup-450ml"
response = requests.get(url)
if response.status_code == 200:
    netmed_responses = response.text
    print(f"HTML content fetched.")
else:
    print(f"Failed to fetch webpage for . Status code: {response.status_code}")

# Step 3: Process fetched data
netmeds_data = []

def get_li_p_text(block):
    block_text = ''
    for ddesc in block.children:
        if ddesc.name == 'p':
            block_text += '\n' + ddesc.get_text() + '\n'
        elif ddesc.name == 'ul':
            block_text += '\n'.join(para.get_text() for para in ddesc.find_all('li'))
        elif ddesc.name == 'table':
            table_data = ddesc.find_all('tr')
            for i, data_point in enumerate(table_data):
                data_point = data_point.get_text()
                block_text += data_point + '\n'
    return block_text

# content = soup.find('div', class_='zV').get_text()
# print(content)

for keyword in netmed_responses:
    try:
        soup = BeautifulSoup(netmed_responses, 'html.parser')
        # prod_name = soup.find('div', class_='product-right-block').find('div', class_='prodName').find('h1').get_text()
        content = soup.find('div', class_='zV')#.get_text()
        #print(content)
        for block in content:
            try:
                block_title = soup.find('div', class_='zV').get_text()
                # print (block_title)
                if 'About' in block_title:
                    About = '\n'.join(para.get_text() for para in block.find_all('p'))
                    # print(About)
                elif 'Uses of' in block_title:
                    uses_of = '\n'.join(para.get_text() for para in block.find_all('p'))
                    print(uses_of)
                elif 'Medicinal Benefits' in block_title:
                    Medicinal_Benefits = '\n'.join(para.get_text() for para in block.find_all('p'))
                    # print(Medicinal_Benefits)
                # elif 'Directions for Use' in block_title:
                #     dir_of_use = '\n'.join(para.get_text() for para in block.find_all('p'))

                # elif 'UNCOMMON' in block_title:
                #     uncommon_text = get_li_p_text(block)
                # elif 'COMMON' in block_title:
                #     common_text = get_li_p_text(block)                    
                # elif 'RARE' in block_title:
                #     rare_text = get_li_p_text(block)
                # elif 'HOW TO MANAGE' in block_title:
                #     how_to_manage = '\n'.join(para.get_text() for para in block.find_all('p'))
                # elif 'WARNING' in block_title:
                #     warning_text = ''
                #     headers = block.find_all('h6')
                #     content = block.find_all('p')
                #     for i, header in enumerate(headers):
                #         warning_text += header.get_text() + '\n' + content[i].get_text() + '\n'
                #     # print(warning_text)
                        
                # elif 'OTHERS' in block_title:
                #     others_text = get_li_p_text(block)
                # elif 'INTERACTIONS' in block_title:
                #     interactions = get_li_p_text(block)
                # elif 'SYNOPSIS' in block_title:
                #     synopsis = get_li_p_text(block)
                # elif 'MORE INFORMATION' in block_title:
                #     more_info = get_li_p_text(block)
                # elif 'FAQs' in block_title:
                #     faqs = get_li_p_text(block)
                # elif 'REFERENCES' in block_title:
                #     references = get_li_p_text(block)
                # elif 'USEFUL DIAGNOSTIC TESTS' in block_title:
                #     useful_diagnostic_tests = get_li_p_text(block)
            except Exception as e:
                print(e)
        
        # prescript_content_div = soup.find('div', class_='left-block').find_all('div', class_='drug-content')[1].find('div', class_='prescript-txt')
        # prescript_content_titles = prescript_content_div.find_all('div', class_='manufacturer_name')
        # prescript_content_titles.extend(prescript_content_div.find_all('div', class_='manufacturer_address'))
        # prescript_content_data = prescript_content_div.find_all('div', class_='manufacturer__name_value')
        # prescript_content_data.extend(prescript_content_div.find_all('div', class_='manufacturer_address_value'))
        # for i,t in enumerate(prescript_content_titles):
        #     continue
        #     # print (t.get_text())
        #     # print (prescript_content_data[i].get_text())
        # netmeds_row = {
        #     'prod_name': prod_name,
        #     'introduction': introduction,
        #     'uses_of': uses_of,
        #     'how_it_works': how_it_works,
        #     'dir_of_use': dir_of_use,
        #     'uncommon_text': uncommon_text,
        #     'common_text': common_text,
        #     'rare_text': rare_text,
        #     'how_to_manage': how_to_manage,
        #     'warning_text': warning_text,
        #     'others_text': others_text,
        #     'interactions': interactions,
        #     'synopsis': synopsis, 
        #     'more_info': more_info,
        #     'faqs':faqs, 
        #     'references': references,
        #     'useful_diagnostic_tests': useful_diagnostic_tests
        # }
        # netmeds_data.append(netmeds_row)
        # # netmeds_dict[keyword] = netmeds_row
    except Exception as e:
        print (e)

# Step 4: Save processed data into a new CSV file
with open('netmeds1_data.csv', 'w', newline='', encoding='utf-8') as csvfile:
    fieldnames = ['prod_name', 'introduction', 'uses_of','how_it_works','dir_of_use','uncommon_text','common_text','rare_text','how_to_manage','warning_text','others_text','interactions','synopsis','more_info','faqs','references','useful_diagnostic_tests']  # Update with your field names
    writer = DictWriter(csvfile, fieldnames=fieldnames)
    writer.writeheader()
    writer.writerows(netmeds_data)

print("Data saved to netmeds_data.csv.")
# Out:
# HTML content fetched.
